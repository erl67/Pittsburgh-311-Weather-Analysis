# %% [markdown]
# https://github.com/dbabichenko/python_for_data_and_analytics/tree/master/12%20-%20Classification

# %%
# Required Python Machine learning Packages
import pandas as pd
import numpy as np
import operator

# To split the dataset into train and test datasets
from sklearn.model_selection import train_test_split

# Classifiers
from sklearn.naive_bayes import GaussianNB
from sklearn import svm
from sklearn.neighbors import KNeighborsRegressor
from sklearn.ensemble import RandomForestRegressor
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier, export_graphviz

from sklearn.model_selection import cross_val_score, cross_val_predict
from sklearn.feature_selection import RFE
from sklearn.feature_selection import SelectKBest
from sklearn.feature_selection import chi2
from sklearn.decomposition import PCA
from sklearn.ensemble import ExtraTreesClassifier

# To calculate the accuracy score of the model
from sklearn.preprocessing import LabelEncoder
from sklearn import metrics

import matplotlib.pyplot as plt
# %matplotlib inline

# %%
def label_encode(df, columns):
    for col in columns:
        le = LabelEncoder()
        col_values_unique = list(df[col].unique())
        le_fitted = le.fit(col_values_unique)
 
        col_values = list(df[col].values)
        #le.classes_
        col_values_transformed = le.transform(col_values)
        df[col] = col_values_transformed

# %%
def classify(predictors, response, classifier = 'svm', kern='rbf', neighbors=3, kfolds=0, report=False, features_select=0):        
    # split X and y into training and testing sets
    X_train, X_test, y_train, y_test = train_test_split(predictors, response, test_size=0.20, random_state=1)

    
    if classifier == 'nb':
        cl = GaussianNB() # instantiate model
        msg = 'Naive Bayes'
    elif classifier == 'svm':
        cl = svm.SVC(kernel=kern) # instantiate model
        msg = 'SVM with ' + kern + ' kernel'
    elif classifier == 'knn':
        cl = KNeighborsRegressor(n_neighbors=neighbors)
        msg = 'KNN with k=' + str(neighbors)
    elif classifier == 'rf':
        # Instantiate model with  decision trees
        # Note that the number of decision trees is denoted
        # using the neighbors parameter, which is set to 3 by default
        cl = RandomForestRegressor(n_estimators = 1000, random_state = 42)
        msg = 'Random Forest with ' + str(neighbors) + ' decision trees'
    elif classifier == 'dtree':
        cl = DecisionTreeClassifier(min_samples_split=20, random_state=99)
        msg = 'Decision tree'
    elif classifier == 'logisticregression':
        cl = LogisticRegression()
        msg = 'Logistic Regression'
        
    model = cl.fit(X_train, y_train)
    y_pred_class = model.predict(X_test)
    print(msg + ' model accuracy score: ', metrics.accuracy_score(y_test, y_pred_class.round()))
    
    if kfolds > 0:
        # Perform k-fold cross validation
        scores = cross_val_score(model, predictors, response, cv=kfolds)
        print('Cross-validated score:', scores.mean())
    
    if report == True:
        print('Confusion matrix')
        print(metrics.confusion_matrix(y_test, y_pred_class)) # confusion matrix
        print('Classification report')
        target_names=['low','med','high']
        print(metrics.classification_report(y_test, y_pred_class, target_names=target_names))
        
        print('______________________________')
    
    if features_select > 0:
        test = SelectKBest(score_func=chi2, k=features_select)
        fit = test.fit(predictors, response)
        
        # summarize scores
        np.set_printoptions(precision=3)
        # print(fit.scores_)
        features_scores = {}
        for i in range(0, len(predictors.columns)):
            features_scores[predictors.columns[i]] = fit.scores_[i]
            
        # print(features_scores)
        sorted_features_scores = sorted(features_scores.items(), key=operator.itemgetter(1))
        print(sorted_features_scores[-5:])

# %%
def decompose(predictors):
    # feature extraction
    pca = PCA(n_components=3)
    fit = pca.fit(predictors)
    
    # summarize components
    # print(fit.explained_variance_ratio_)
    # print(fit.components_)
    return pd.DataFrame(fit.components_)

# %%
df = pd.read_csv("311TrimmedGrouped.csv")
df.head()
# Out:
#    Unnamed: 0  REQUEST_ID           CREATED_ON REQUEST_TYPE REQUEST_ORIGIN  \
# 0          13      205276  2017-12-31T13:42:00     Potholes        Website
# 1          75      205180  2017-12-29T17:45:00     Potholes        Website
# 2          96      205151  2017-12-29T14:58:00     Potholes    Call Center
# 3         112      205130  2017-12-29T14:03:00     Potholes    Call Center
# 4         133      205098  2017-12-29T12:40:00     Potholes    Call Center
#
#    STATUS                DEPARTMENT   NEIGHBORHOOD  COUNCIL_DISTRICT  WARD  \
# 0       1  DPW - Street Maintenance      Beechview               4.0  19.0
# 1       1  DPW - Street Maintenance     Manchester               6.0  21.0
# 2       1  DPW - Street Maintenance  Regent Square               9.0  14.0
# 3       1  DPW - Street Maintenance      Brookline               4.0  19.0
# 4       1  DPW - Street Maintenance  Lincoln Place               5.0  31.0
#
#        ...        daily.temperatureMinTime  daily.time  daily.uvIndex  \
# 0      ...                      1514721600  1514696400              1
# 1      ...                      1514541600  1514523600              1
# 2      ...                      1514541600  1514523600              1
# 3      ...                      1514541600  1514523600              1
# 4      ...                      1514541600  1514523600              1
#
#    daily.uvIndexTime daily.visibility  daily.windBearing  daily.windGust  \
# 0         1514732400             9.10                261            5.37
# 1         1514559600             8.58                253            8.96
# 2         1514559600             8.28                252            8.98
# 3         1514559600             8.59                253            9.22
# 4         1514559600             8.32                252            9.37
#
#   daily.windGustTime  daily.windSpeed  REQUEST_GROUP
# 0         1514696400             0.56          Roads
# 1         1514577600             1.31          Roads
# 2         1514577600             1.26          Roads
# 3         1514577600             1.30          Roads
# 4         1514577600             1.29          Roads
#
# [5 rows x 75 columns]

# %%
df.fillna(0, inplace=True) #fill zero instances of weather
df = df.reset_index()

# %%
df.columns
# Out:
# Index(['index', 'Unnamed: 0', 'REQUEST_ID', 'CREATED_ON', 'REQUEST_TYPE',
#        'REQUEST_ORIGIN', 'STATUS', 'DEPARTMENT', 'NEIGHBORHOOD',
#        'COUNCIL_DISTRICT', 'WARD', 'TRACT', 'PUBLIC_WORKS_DIVISION',
#        'PLI_DIVISION', 'POLICE_ZONE', 'FIRE_ZONE', 'X', 'Y', 'GEO_ACCURACY',
#        'current.apparentTemperature', 'current.cloudCover', 'current.dewPoint',
#        'current.humidity', 'current.icon', 'current.precipIntensity',
#        'current.precipProbability', 'current.precipType', 'current.pressure',
#        'current.summary', 'current.temperature', 'current.time',
#        'current.uvIndex', 'current.visibility', 'current.windBearing',
#        'current.windGust', 'current.windSpeed',
#        'daily.apparentTemperatureHigh', 'daily.apparentTemperatureHighTime',
#        'daily.apparentTemperatureLow', 'daily.apparentTemperatureLowTime',
#        'daily.apparentTemperatureMax', 'daily.apparentTemperatureMaxTime',
#        'daily.apparentTemperatureMin', 'daily.apparentTemperatureMinTime',
#        'daily.cloudCover', 'daily.dewPoint', 'daily.humidity', 'daily.icon',
#        'daily.moonPhase', 'daily.precipAccumulation', 'daily.precipIntensity',
#        'daily.precipIntensityMax', 'daily.precipIntensityMaxTime',
#        'daily.precipProbability', 'daily.precipType', 'daily.pressure',
#        'daily.summary', 'daily.sunriseTime', 'daily.sunsetTime',
#        'daily.temperatureHigh', 'daily.temperatureHighTime',
#        'daily.temperatureLow', 'daily.temperatureLowTime',
#        'daily.temperatureMax', 'daily.temperatureMaxTime',
#        'daily.temperatureMin', 'daily.temperatureMinTime', 'daily.time',
#        'daily.uvIndex', 'daily.uvIndexTime', 'daily.visibility',
#        'daily.windBearing', 'daily.windGust', 'daily.windGustTime',
#        'daily.windSpeed', 'REQUEST_GROUP'],
#       dtype='object')

# %%
df.corr()
# Out:
#                                       index  Unnamed: 0  REQUEST_ID    STATUS  \
# index                              1.000000   -0.051815    0.052628 -0.049882
# Unnamed: 0                        -0.051815    1.000000   -0.999832 -0.009968
# REQUEST_ID                         0.052628   -0.999832    1.000000  0.010486
# STATUS                            -0.049882   -0.009968    0.010486  1.000000
# COUNCIL_DISTRICT                  -0.071076    0.041724   -0.041505  0.005129
# WARD                               0.009420   -0.029995    0.029464  0.004965
# TRACT                             -0.009921   -0.012563    0.012534  0.008233
# PUBLIC_WORKS_DIVISION             -0.028873   -0.001909    0.001780 -0.025449
# PLI_DIVISION                       0.009420   -0.029995    0.029464  0.004965
# POLICE_ZONE                       -0.075824    0.015102   -0.015286 -0.022022
# X                                 -0.059970    0.040363   -0.040154  0.003031
# Y                                  0.026881   -0.001772    0.001893  0.024175
# current.apparentTemperature       -0.117956   -0.221854    0.209526 -0.022072
# current.cloudCover                 0.043788    0.219047   -0.214991  0.010790
# current.dewPoint                  -0.105901   -0.252950    0.240115 -0.014588
# current.humidity                   0.006891   -0.129303    0.125623  0.015455
# current.precipIntensity           -0.017897    0.068511   -0.068115  0.003919
# current.precipProbability         -0.014544    0.178832   -0.177064  0.007254
# current.pressure                   0.049646   -0.215991    0.219260 -0.003600
# current.temperature               -0.117159   -0.218763    0.206438 -0.021850
# current.time                       0.053674   -0.996814    0.997775  0.012227
# current.uvIndex                   -0.046340    0.004025   -0.008540 -0.019767
# current.visibility                -0.059624    0.017910   -0.017134 -0.012931
# current.windBearing                0.027995    0.136984   -0.133651  0.005802
# current.windGust                  -0.006352    0.298270   -0.291795 -0.004430
# current.windSpeed                 -0.006610    0.335240   -0.327501  0.000493
# daily.apparentTemperatureHigh     -0.127408   -0.260271    0.247182 -0.016925
# daily.apparentTemperatureHighTime  0.053675   -0.996817    0.997774  0.012244
# daily.apparentTemperatureLow      -0.117774   -0.235579    0.222719 -0.018935
# daily.apparentTemperatureLowTime   0.053700   -0.996825    0.997782  0.012258
# ...                                     ...         ...         ...       ...
# daily.apparentTemperatureMin      -0.111831   -0.250201    0.236886 -0.018414
# daily.apparentTemperatureMinTime   0.053694   -0.996798    0.997763  0.012299
# daily.cloudCover                   0.043304    0.260857   -0.256250  0.010364
# daily.dewPoint                    -0.104506   -0.267445    0.254356 -0.014939
# daily.humidity                     0.021599   -0.156085    0.152819  0.002835
# daily.moonPhase                   -0.042461    0.013021   -0.014604  0.005291
# daily.precipAccumulation           0.086891    0.154749   -0.153436  0.004531
# daily.precipIntensity             -0.058433    0.101483   -0.101833  0.010197
# daily.precipIntensityMax          -0.057827    0.057184   -0.059325  0.005452
# daily.precipIntensityMaxTime      -0.009798    0.154768   -0.154193  0.010605
# daily.precipProbability           -0.072147    0.237420   -0.236794  0.007702
# daily.pressure                     0.062838   -0.226059    0.229555 -0.007466
# daily.sunriseTime                  0.053731   -0.996805    0.997769  0.012265
# daily.sunsetTime                   0.053625   -0.996831    0.997784  0.012255
# daily.temperatureHigh             -0.131327   -0.256318    0.243279 -0.016284
# daily.temperatureHighTime          0.053697   -0.996822    0.997777  0.012243
# daily.temperatureLow              -0.117273   -0.224238    0.211381 -0.018497
# daily.temperatureLowTime           0.053694   -0.996827    0.997784  0.012256
# daily.temperatureMax              -0.130060   -0.246723    0.233562 -0.015923
# daily.temperatureMaxTime           0.053455   -0.996832    0.997783  0.012252
# daily.temperatureMin              -0.109016   -0.246287    0.232976 -0.019003
# daily.temperatureMinTime           0.053698   -0.996791    0.997759  0.012299
# daily.time                         0.053694   -0.996810    0.997771  0.012262
# daily.uvIndex                     -0.125977   -0.032840    0.020121 -0.014554
# daily.uvIndexTime                  0.053661   -0.996819    0.997777  0.012261
# daily.visibility                  -0.071600   -0.030910    0.029375 -0.006097
# daily.windBearing                  0.024039    0.075709   -0.075120  0.006358
# daily.windGust                    -0.043074    0.401221   -0.395048  0.009309
# daily.windGustTime                 0.053474   -0.996832    0.997785  0.012293
# daily.windSpeed                   -0.015342    0.415942   -0.407309  0.007724
#
#                                    COUNCIL_DISTRICT      WARD     TRACT  \
# index                                     -0.071076  0.009420 -0.009921
# Unnamed: 0                                 0.041724 -0.029995 -0.012563
# REQUEST_ID                                -0.041505  0.029464  0.012534
# STATUS                                     0.005129  0.004965  0.008233
# COUNCIL_DISTRICT                           1.000000 -0.610653 -0.383170
# WARD                                      -0.610653  1.000000  0.444382
# TRACT                                     -0.383170  0.444382  1.000000
# PUBLIC_WORKS_DIVISION                     -0.252472  0.072012  0.113109
# PLI_DIVISION                              -0.610653  1.000000  0.444382
# POLICE_ZONE                                0.332147 -0.138735  0.009178
# X                                          0.780811 -0.500677 -0.298280
# Y                                          0.298943 -0.381241 -0.199405
# current.apparentTemperature               -0.016890  0.023369  0.003725
# current.cloudCover                         0.018489 -0.032123 -0.019601
# current.dewPoint                          -0.011981  0.027451  0.000745
# current.humidity                           0.009953  0.021400 -0.006731
# current.precipIntensity                    0.001802 -0.002429 -0.000553
# current.precipProbability                  0.028833 -0.032387 -0.020133
# current.pressure                          -0.012183  0.014437  0.014085
# current.temperature                       -0.016400  0.022638  0.002961
# current.time                              -0.042098  0.029981  0.013949
# current.uvIndex                           -0.011287  0.019145  0.005887
# current.visibility                        -0.023399  0.018742  0.015945
# current.windBearing                        0.020636 -0.033683 -0.015277
# current.windGust                           0.018389 -0.029855 -0.014324
# current.windSpeed                          0.013485 -0.027283 -0.011780
# daily.apparentTemperatureHigh             -0.021524  0.039442  0.014053
# daily.apparentTemperatureHighTime         -0.042120  0.030036  0.013999
# daily.apparentTemperatureLow              -0.021511  0.035834  0.018321
# daily.apparentTemperatureLowTime          -0.042075  0.029979  0.013952
# ...                                             ...       ...       ...
# daily.apparentTemperatureMin              -0.015568  0.025436  0.005320
# daily.apparentTemperatureMinTime          -0.042045  0.029910  0.013893
# daily.cloudCover                           0.019148 -0.033522 -0.020284
# daily.dewPoint                            -0.017444  0.034978  0.005454
# daily.humidity                            -0.005478  0.028769 -0.008657
# daily.moonPhase                           -0.019226  0.019660  0.016493
# daily.precipAccumulation                   0.030716 -0.041593 -0.016825
# daily.precipIntensity                      0.004315  0.003832  0.001460
# daily.precipIntensityMax                  -0.002576  0.012655  0.005261
# daily.precipIntensityMaxTime               0.019373 -0.027228 -0.013264
# daily.precipProbability                    0.017853 -0.018713 -0.007262
# daily.pressure                            -0.009922  0.006021  0.008890
# daily.sunriseTime                         -0.042093  0.029984  0.013965
# daily.sunsetTime                          -0.042107  0.030030  0.013982
# daily.temperatureHigh                     -0.021599  0.039496  0.014509
# daily.temperatureHighTime                 -0.042100  0.030010  0.013987
# daily.temperatureLow                      -0.020506  0.034067  0.017061
# daily.temperatureLowTime                  -0.042083  0.029986  0.013953
# daily.temperatureMax                      -0.021524  0.038766  0.013146
# daily.temperatureMaxTime                  -0.042189  0.030139  0.014049
# daily.temperatureMin                      -0.014441  0.023906  0.004035
# daily.temperatureMinTime                  -0.042063  0.029914  0.013886
# daily.time                                -0.042095  0.029998  0.013969
# daily.uvIndex                             -0.018534  0.055869  0.022993
# daily.uvIndexTime                         -0.042107  0.030016  0.013980
# daily.visibility                          -0.017932  0.026315  0.018206
# daily.windBearing                          0.015295 -0.017567 -0.018241
# daily.windGust                             0.022818 -0.018364 -0.007101
# daily.windGustTime                        -0.042138  0.030069  0.014017
# daily.windSpeed                            0.025142 -0.032200 -0.009092
#
#                                    PUBLIC_WORKS_DIVISION  PLI_DIVISION  \
# index                                          -0.028873      0.009420
# Unnamed: 0                                     -0.001909     -0.029995
# REQUEST_ID                                      0.001780      0.029464
# STATUS                                         -0.025449      0.004965
# COUNCIL_DISTRICT                               -0.252472     -0.610653
# WARD                                            0.072012      1.000000
# TRACT                                           0.113109      0.444382
# PUBLIC_WORKS_DIVISION                           1.000000      0.072012
# PLI_DIVISION                                    0.072012      1.000000
# POLICE_ZONE                                     0.378562     -0.138735
# X                                              -0.400006     -0.500677
# Y                                              -0.598584     -0.381241
# current.apparentTemperature                     0.007789      0.023369
# current.cloudCover                             -0.012312     -0.032123
# current.dewPoint                                0.009188      0.027451
# current.humidity                                0.006833      0.021400
# current.precipIntensity                         0.001080     -0.002429
# current.precipProbability                      -0.011905     -0.032387
# current.pressure                               -0.003371      0.014437
# current.temperature                             0.007500      0.022638
# current.time                                    0.002740      0.029981
# current.uvIndex                                 0.006222      0.019145
# current.visibility                              0.010709      0.018742
# current.windBearing                            -0.005709     -0.033683
# current.windGust                               -0.012923     -0.029855
# current.windSpeed                              -0.005890     -0.027283
# daily.apparentTemperatureHigh                   0.012625      0.039442
# daily.apparentTemperatureHighTime               0.002772      0.030036
# daily.apparentTemperatureLow                    0.010250      0.035834
# daily.apparentTemperatureLowTime                0.002754      0.029979
# ...                                                  ...           ...
# daily.apparentTemperatureMin                    0.006527      0.025436
# daily.apparentTemperatureMinTime                0.002746      0.029910
# daily.cloudCover                               -0.000969     -0.033522
# daily.dewPoint                                  0.011718      0.034978
# daily.humidity                                  0.009096      0.028769
# daily.moonPhase                                 0.014143      0.019660
# daily.precipAccumulation                       -0.010205     -0.041593
# daily.precipIntensity                           0.000562      0.003832
# daily.precipIntensityMax                        0.001097      0.012655
# daily.precipIntensityMaxTime                   -0.001427     -0.027228
# daily.precipProbability                         0.001843     -0.018713
# daily.pressure                                 -0.005534      0.006021
# daily.sunriseTime                               0.002761      0.029984
# daily.sunsetTime                                0.002776      0.030030
# daily.temperatureHigh                           0.012755      0.039496
# daily.temperatureHighTime                       0.002763      0.030010
# daily.temperatureLow                            0.010732      0.034067
# daily.temperatureLowTime                        0.002755      0.029986
# daily.temperatureMax                            0.013630      0.038766
# daily.temperatureMaxTime                        0.002805      0.030139
# daily.temperatureMin                            0.006943      0.023906
# daily.temperatureMinTime                        0.002764      0.029914
# daily.time                                      0.002765      0.029998
# daily.uvIndex                                   0.023192      0.055869
# daily.uvIndexTime                               0.002776      0.030016
# daily.visibility                                0.006160      0.026315
# daily.windBearing                               0.004018     -0.017567
# daily.windGust                                 -0.001536     -0.018364
# daily.windGustTime                              0.002802      0.030069
# daily.windSpeed                                -0.002251     -0.032200
#
#                                    POLICE_ZONE       ...         \
# index                                -0.075824       ...
# Unnamed: 0                            0.015102       ...
# REQUEST_ID                           -0.015286       ...
# STATUS                               -0.022022       ...
# COUNCIL_DISTRICT                      0.332147       ...
# WARD                                 -0.138735       ...
# TRACT                                 0.009178       ...
# PUBLIC_WORKS_DIVISION                 0.378562       ...
# PLI_DIVISION                         -0.138735       ...
# POLICE_ZONE                           1.000000       ...
# X                                     0.222210       ...
# Y                                    -0.209840       ...
# current.apparentTemperature           0.001444       ...
# current.cloudCover                   -0.008407       ...
# current.dewPoint                      0.008221       ...
# current.humidity                      0.021413       ...
# current.precipIntensity               0.002727       ...
# current.precipProbability             0.000822       ...
# current.pressure                      0.005232       ...
# current.temperature                   0.001511       ...
# current.time                         -0.015530       ...
# current.uvIndex                      -0.002036       ...
# current.visibility                   -0.004716       ...
# current.windBearing                   0.001938       ...
# current.windGust                     -0.004775       ...
# current.windSpeed                    -0.004261       ...
# daily.apparentTemperatureHigh         0.006807       ...
# daily.apparentTemperatureHighTime    -0.015499       ...
# daily.apparentTemperatureLow          0.005212       ...
# daily.apparentTemperatureLowTime     -0.015506       ...
# ...                                        ...       ...
# daily.apparentTemperatureMin          0.004033       ...
# daily.apparentTemperatureMinTime     -0.015529       ...
# daily.cloudCover                     -0.003918       ...
# daily.dewPoint                        0.007772       ...
# daily.humidity                        0.012584       ...
# daily.moonPhase                       0.003156       ...
# daily.precipAccumulation             -0.000958       ...
# daily.precipIntensity                 0.004047       ...
# daily.precipIntensityMax             -0.002790       ...
# daily.precipIntensityMaxTime         -0.003360       ...
# daily.precipProbability              -0.003848       ...
# daily.pressure                        0.004269       ...
# daily.sunriseTime                    -0.015519       ...
# daily.sunsetTime                     -0.015501       ...
# daily.temperatureHigh                 0.006513       ...
# daily.temperatureHighTime            -0.015503       ...
# daily.temperatureLow                  0.005008       ...
# daily.temperatureLowTime             -0.015510       ...
# daily.temperatureMax                  0.005841       ...
# daily.temperatureMaxTime             -0.015504       ...
# daily.temperatureMin                  0.004851       ...
# daily.temperatureMinTime             -0.015536       ...
# daily.time                           -0.015512       ...
# daily.uvIndex                         0.024104       ...
# daily.uvIndexTime                    -0.015507       ...
# daily.visibility                     -0.000418       ...
# daily.windBearing                     0.004428       ...
# daily.windGust                        0.008654       ...
# daily.windGustTime                   -0.015506       ...
# daily.windSpeed                       0.005043       ...
#
#                                    daily.temperatureMin  \
# index                                         -0.109016
# Unnamed: 0                                    -0.246287
# REQUEST_ID                                     0.232976
# STATUS                                        -0.019003
# COUNCIL_DISTRICT                              -0.014441
# WARD                                           0.023906
# TRACT                                          0.004035
# PUBLIC_WORKS_DIVISION                          0.006943
# PLI_DIVISION                                   0.023906
# POLICE_ZONE                                    0.004851
# X                                             -0.018560
# Y                                              0.007793
# current.apparentTemperature                    0.913804
# current.cloudCover                            -0.137850
# current.dewPoint                               0.949742
# current.humidity                               0.267064
# current.precipIntensity                        0.070261
# current.precipProbability                      0.026551
# current.pressure                              -0.262588
# current.temperature                            0.913665
# current.time                                   0.201213
# current.uvIndex                                0.219065
# current.visibility                            -0.041788
# current.windBearing                           -0.212980
# current.windGust                              -0.359348
# current.windSpeed                             -0.399993
# daily.apparentTemperatureHigh                  0.918941
# daily.apparentTemperatureHighTime              0.201384
# daily.apparentTemperatureLow                   0.901820
# daily.apparentTemperatureLowTime               0.201453
# ...                                                 ...
# daily.apparentTemperatureMin                   0.996953
# daily.apparentTemperatureMinTime               0.201065
# daily.cloudCover                              -0.146351
# daily.dewPoint                                 0.967770
# daily.humidity                                 0.324830
# daily.moonPhase                                0.061932
# daily.precipAccumulation                      -0.209872
# daily.precipIntensity                          0.223929
# daily.precipIntensityMax                       0.318578
# daily.precipIntensityMaxTime                   0.071687
# daily.precipProbability                        0.178950
# daily.pressure                                -0.287147
# daily.sunriseTime                              0.201048
# daily.sunsetTime                               0.201670
# daily.temperatureHigh                          0.915712
# daily.temperatureHighTime                      0.201414
# daily.temperatureLow                           0.904968
# daily.temperatureLowTime                       0.201532
# daily.temperatureMax                           0.915312
# daily.temperatureMaxTime                       0.201847
# daily.temperatureMin                           1.000000
# daily.temperatureMinTime                       0.200869
# daily.time                                     0.201228
# daily.uvIndex                                  0.615083
# daily.uvIndexTime                              0.201391
# daily.visibility                               0.082796
# daily.windBearing                             -0.122839
# daily.windGust                                -0.314277
# daily.windGustTime                             0.201794
# daily.windSpeed                               -0.444652
#
#                                    daily.temperatureMinTime  daily.time  \
# index                                              0.053698    0.053694
# Unnamed: 0                                        -0.996791   -0.996810
# REQUEST_ID                                         0.997759    0.997771
# STATUS                                             0.012299    0.012262
# COUNCIL_DISTRICT                                  -0.042063   -0.042095
# WARD                                               0.029914    0.029998
# TRACT                                              0.013886    0.013969
# PUBLIC_WORKS_DIVISION                              0.002764    0.002765
# PLI_DIVISION                                       0.029914    0.029998
# POLICE_ZONE                                       -0.015536   -0.015512
# X                                                 -0.040725   -0.040723
# Y                                                  0.000554    0.000541
# current.apparentTemperature                        0.178642    0.178904
# current.cloudCover                                -0.206520   -0.207409
# current.dewPoint                                   0.206002    0.206144
# current.humidity                                   0.110059    0.109876
# current.precipIntensity                           -0.067762   -0.068211
# current.precipProbability                         -0.175600   -0.176057
# current.pressure                                   0.219883    0.220465
# current.temperature                                0.175647    0.175875
# current.time                                       0.999994    0.999999
# current.uvIndex                                   -0.016926   -0.016655
# current.visibility                                -0.009362   -0.009233
# current.windBearing                               -0.122575   -0.123497
# current.windGust                                  -0.275361   -0.276131
# current.windSpeed                                 -0.308185   -0.308903
# daily.apparentTemperatureHigh                      0.215839    0.216570
# daily.apparentTemperatureHighTime                  0.999993    0.999999
# daily.apparentTemperatureLow                       0.191762    0.192903
# daily.apparentTemperatureLowTime                   0.999994    0.999999
# ...                                                     ...         ...
# daily.apparentTemperatureMin                       0.204599    0.205003
# daily.apparentTemperatureMinTime                   0.999999    0.999995
# daily.cloudCover                                  -0.247063   -0.247910
# daily.dewPoint                                     0.219556    0.219877
# daily.humidity                                     0.131642    0.131273
# daily.moonPhase                                   -0.013255   -0.013197
# daily.precipAccumulation                          -0.151157   -0.151402
# daily.precipIntensity                             -0.103226   -0.103947
# daily.precipIntensityMax                          -0.062783   -0.063413
# daily.precipIntensityMaxTime                      -0.156581   -0.157224
# daily.precipProbability                           -0.239708   -0.240131
# daily.pressure                                     0.230315    0.230728
# daily.sunriseTime                                  0.999995    1.000000
# daily.sunsetTime                                   0.999994    1.000000
# daily.temperatureHigh                              0.211946    0.212663
# daily.temperatureHighTime                          0.999993    1.000000
# daily.temperatureLow                               0.180081    0.181209
# daily.temperatureLowTime                           0.999994    0.999999
# daily.temperatureMax                               0.201789    0.202428
# daily.temperatureMaxTime                           0.999989    0.999998
# daily.temperatureMin                               0.200869    0.201228
# daily.temperatureMinTime                           1.000000    0.999995
# daily.time                                         0.999995    1.000000
# daily.uvIndex                                      0.002737    0.003433
# daily.uvIndexTime                                  0.999995    1.000000
# daily.visibility                                   0.036086    0.036383
# daily.windBearing                                 -0.069400   -0.070175
# daily.windGust                                    -0.375930   -0.376729
# daily.windGustTime                                 0.999991    0.999998
# daily.windSpeed                                   -0.384653   -0.385400
#
#                                    daily.uvIndex  daily.uvIndexTime  \
# index                                  -0.125977           0.053661
# Unnamed: 0                             -0.032840          -0.996819
# REQUEST_ID                              0.020121           0.997777
# STATUS                                 -0.014554           0.012261
# COUNCIL_DISTRICT                       -0.018534          -0.042107
# WARD                                    0.055869           0.030016
# TRACT                                   0.022993           0.013980
# PUBLIC_WORKS_DIVISION                   0.023192           0.002776
# PLI_DIVISION                            0.055869           0.030016
# POLICE_ZONE                             0.024104          -0.015507
# X                                      -0.022269          -0.040733
# Y                                      -0.027130           0.000526
# current.apparentTemperature             0.605576           0.179056
# current.cloudCover                     -0.472735          -0.207471
# current.dewPoint                        0.554159           0.206289
# current.humidity                       -0.024242           0.109884
# current.precipIntensity                -0.077800          -0.068186
# current.precipProbability              -0.210769          -0.176076
# current.pressure                       -0.025536           0.220422
# current.temperature                     0.603723           0.176027
# current.time                            0.003403           0.999999
# current.uvIndex                         0.325905          -0.016587
# current.visibility                      0.127095          -0.009218
# current.windBearing                    -0.203326          -0.123557
# current.windGust                       -0.325934          -0.276209
# current.windSpeed                      -0.394789          -0.309001
# daily.apparentTemperatureHigh           0.723141           0.216743
# daily.apparentTemperatureHighTime       0.003782           0.999999
# daily.apparentTemperatureLow            0.664901           0.193061
# daily.apparentTemperatureLowTime        0.003576           0.999999
# ...                                          ...                ...
# daily.apparentTemperatureMin            0.620189           0.205168
# daily.apparentTemperatureMinTime        0.002878           0.999995
# daily.cloudCover                       -0.554177          -0.248015
# daily.dewPoint                          0.573871           0.220025
# daily.humidity                         -0.196515           0.131235
# daily.moonPhase                         0.020949          -0.013165
# daily.precipAccumulation               -0.138639          -0.151447
# daily.precipIntensity                  -0.062773          -0.103937
# daily.precipIntensityMax                0.035744          -0.063385
# daily.precipIntensityMaxTime           -0.218427          -0.157266
# daily.precipProbability                -0.172975          -0.240163
# daily.pressure                         -0.055502           0.230681
# daily.sunriseTime                       0.003225           1.000000
# daily.sunsetTime                        0.003930           1.000000
# daily.temperatureHigh                   0.729790           0.212839
# daily.temperatureHighTime               0.003790           1.000000
# daily.temperatureLow                    0.660990           0.181367
# daily.temperatureLowTime                0.003609           0.999999
# daily.temperatureMax                    0.727255           0.202605
# daily.temperatureMaxTime                0.004271           0.999998
# daily.temperatureMin                    0.615083           0.201391
# daily.temperatureMinTime                0.002737           0.999995
# daily.time                              0.003433           1.000000
# daily.uvIndex                           1.000000           0.003681
# daily.uvIndexTime                       0.003681           1.000000
# daily.visibility                        0.292680           0.036451
# daily.windBearing                      -0.044383          -0.070206
# daily.windGust                         -0.236298          -0.376779
# daily.windGustTime                      0.004037           0.999998
# daily.windSpeed                        -0.406758          -0.385502
#
#                                    daily.visibility  daily.windBearing  \
# index                                     -0.071600           0.024039
# Unnamed: 0                                -0.030910           0.075709
# REQUEST_ID                                 0.029375          -0.075120
# STATUS                                    -0.006097           0.006358
# COUNCIL_DISTRICT                          -0.017932           0.015295
# WARD                                       0.026315          -0.017567
# TRACT                                      0.018206          -0.018241
# PUBLIC_WORKS_DIVISION                      0.006160           0.004018
# PLI_DIVISION                               0.026315          -0.017567
# POLICE_ZONE                               -0.000418           0.004428
# X                                         -0.017295           0.011077
# Y                                         -0.007676           0.001168
# current.apparentTemperature                0.108523          -0.126011
# current.cloudCover                        -0.321649           0.073821
# current.dewPoint                           0.002421          -0.122470
# current.humidity                          -0.288449          -0.038478
# current.precipIntensity                   -0.152066          -0.076972
# current.precipProbability                 -0.258083          -0.050767
# current.pressure                           0.201759          -0.029901
# current.temperature                        0.103499          -0.116211
# current.time                               0.036363          -0.070211
# current.uvIndex                            0.094476          -0.028369
# current.visibility                         0.618793          -0.036978
# current.windBearing                       -0.053575           0.599202
# current.windGust                          -0.007975           0.190923
# current.windSpeed                         -0.012712           0.170243
# daily.apparentTemperatureHigh              0.185416          -0.162081
# daily.apparentTemperatureHighTime          0.036594          -0.070263
# daily.apparentTemperatureLow               0.160731          -0.240627
# daily.apparentTemperatureLowTime           0.036405          -0.070159
# ...                                             ...                ...
# daily.apparentTemperatureMin               0.099905          -0.136165
# daily.apparentTemperatureMinTime           0.036037          -0.069561
# daily.cloudCover                          -0.377715           0.048933
# daily.dewPoint                             0.018318          -0.157085
# daily.humidity                            -0.465181          -0.137257
# daily.moonPhase                           -0.034777          -0.053128
# daily.precipAccumulation                  -0.277970           0.109509
# daily.precipIntensity                     -0.221414          -0.187440
# daily.precipIntensityMax                  -0.137268          -0.146596
# daily.precipIntensityMaxTime              -0.270975           0.006453
# daily.precipProbability                   -0.184459          -0.087286
# daily.pressure                             0.175431           0.030021
# daily.sunriseTime                          0.036319          -0.070165
# daily.sunsetTime                           0.036491          -0.070216
# daily.temperatureHigh                      0.196458          -0.163912
# daily.temperatureHighTime                  0.036593          -0.070261
# daily.temperatureLow                       0.147153          -0.239963
# daily.temperatureLowTime                   0.036400          -0.070139
# daily.temperatureMax                       0.184949          -0.154975
# daily.temperatureMaxTime                   0.036897          -0.070562
# daily.temperatureMin                       0.082796          -0.122839
# daily.temperatureMinTime                   0.036086          -0.069400
# daily.time                                 0.036383          -0.070175
# daily.uvIndex                              0.292680          -0.044383
# daily.uvIndexTime                          0.036451          -0.070206
# daily.visibility                           1.000000          -0.011443
# daily.windBearing                         -0.011443           1.000000
# daily.windGust                             0.058867           0.256381
# daily.windGustTime                         0.036426          -0.070428
# daily.windSpeed                            0.021193           0.221087
#
#                                    daily.windGust  daily.windGustTime  \
# index                                   -0.043074            0.053474
# Unnamed: 0                               0.401221           -0.996832
# REQUEST_ID                              -0.395048            0.997785
# STATUS                                   0.009309            0.012293
# COUNCIL_DISTRICT                         0.022818           -0.042138
# WARD                                    -0.018364            0.030069
# TRACT                                   -0.007101            0.014017
# PUBLIC_WORKS_DIVISION                   -0.001536            0.002802
# PLI_DIVISION                            -0.018364            0.030069
# POLICE_ZONE                              0.008654           -0.015506
# X                                        0.020603           -0.040748
# Y                                       -0.007169            0.000508
# current.apparentTemperature             -0.296371            0.179556
# current.cloudCover                       0.198168           -0.207697
# current.dewPoint                        -0.318309            0.206800
# current.humidity                        -0.173888            0.110099
# current.precipIntensity                  0.079977           -0.068131
# current.precipProbability                0.157241           -0.176129
# current.pressure                        -0.280421            0.220190
# current.temperature                     -0.275699            0.176497
# current.time                            -0.376752            0.999997
# current.uvIndex                         -0.084354           -0.016456
# current.visibility                       0.096657           -0.009230
# current.windBearing                      0.329619           -0.123864
# current.windGust                         0.630954           -0.276580
# current.windSpeed                        0.673714           -0.309369
# daily.apparentTemperatureHigh           -0.355995            0.217335
# daily.apparentTemperatureHighTime       -0.376926            0.999997
# daily.apparentTemperatureLow            -0.404719            0.193532
# daily.apparentTemperatureLowTime        -0.376739            0.999997
# ...                                           ...                 ...
# daily.apparentTemperatureMin            -0.343837            0.205588
# daily.apparentTemperatureMinTime        -0.376080            0.999993
# daily.cloudCover                         0.235006           -0.248206
# daily.dewPoint                          -0.360654            0.220540
# daily.humidity                          -0.243923            0.131412
# daily.moonPhase                         -0.142306           -0.013260
# daily.precipAccumulation                 0.139650           -0.151713
# daily.precipIntensity                    0.158817           -0.103663
# daily.precipIntensityMax                 0.176205           -0.063099
# daily.precipIntensityMaxTime             0.246965           -0.157163
# daily.precipProbability                  0.305764           -0.239963
# daily.pressure                          -0.268323            0.230398
# daily.sunriseTime                       -0.376689            0.999998
# daily.sunsetTime                        -0.376880            0.999998
# daily.temperatureHigh                   -0.345180            0.213440
# daily.temperatureHighTime               -0.376930            0.999997
# daily.temperatureLow                    -0.389022            0.181867
# daily.temperatureLowTime                -0.376736            0.999997
# daily.temperatureMax                    -0.332773            0.203185
# daily.temperatureMaxTime                -0.377130            0.999997
# daily.temperatureMin                    -0.314277            0.201794
# daily.temperatureMinTime                -0.375930            0.999991
# daily.time                              -0.376729            0.999998
# daily.uvIndex                           -0.236298            0.004037
# daily.uvIndexTime                       -0.376779            0.999998
# daily.visibility                         0.058867            0.036426
# daily.windBearing                        0.256381           -0.070428
# daily.windGust                           1.000000           -0.376760
# daily.windGustTime                      -0.376760            1.000000
# daily.windSpeed                          0.890600           -0.385671
#
#                                    daily.windSpeed
# index                                    -0.015342
# Unnamed: 0                                0.415942
# REQUEST_ID                               -0.407309
# STATUS                                    0.007724
# COUNCIL_DISTRICT                          0.025142
# WARD                                     -0.032200
# TRACT                                    -0.009092
# PUBLIC_WORKS_DIVISION                    -0.002251
# PLI_DIVISION                             -0.032200
# POLICE_ZONE                               0.005043
# X                                         0.024145
# Y                                        -0.000404
# current.apparentTemperature              -0.449575
# current.cloudCover                        0.277339
# current.dewPoint                         -0.461150
# current.humidity                         -0.189053
# current.precipIntensity                   0.032267
# current.precipProbability                 0.147244
# current.pressure                         -0.203483
# current.temperature                      -0.424169
# current.time                             -0.385408
# current.uvIndex                          -0.140763
# current.visibility                        0.076385
# current.windBearing                       0.331164
# current.windGust                          0.713345
# current.windSpeed                         0.775687
# daily.apparentTemperatureHigh            -0.529573
# daily.apparentTemperatureHighTime        -0.385635
# daily.apparentTemperatureLow             -0.529393
# daily.apparentTemperatureLowTime         -0.385371
# ...                                            ...
# daily.apparentTemperatureMin             -0.482002
# daily.apparentTemperatureMinTime         -0.384824
# daily.cloudCover                          0.331585
# daily.dewPoint                           -0.498084
# daily.humidity                           -0.230805
# daily.moonPhase                          -0.104550
# daily.precipAccumulation                  0.169785
# daily.precipIntensity                     0.052030
# daily.precipIntensityMax                  0.032108
# daily.precipIntensityMaxTime              0.215584
# daily.precipProbability                   0.248998
# daily.pressure                           -0.186220
# daily.sunriseTime                        -0.385313
# daily.sunsetTime                         -0.385647
# daily.temperatureHigh                    -0.518515
# daily.temperatureHighTime                -0.385649
# daily.temperatureLow                     -0.511554
# daily.temperatureLowTime                 -0.385358
# daily.temperatureMax                     -0.505690
# daily.temperatureMaxTime                 -0.385992
# daily.temperatureMin                     -0.444652
# daily.temperatureMinTime                 -0.384653
# daily.time                               -0.385400
# daily.uvIndex                            -0.406758
# daily.uvIndexTime                        -0.385502
# daily.visibility                          0.021193
# daily.windBearing                         0.221087
# daily.windGust                            0.890600
# daily.windGustTime                       -0.385671
# daily.windSpeed                           1.000000
#
# [62 rows x 62 columns]

# %%
# define X and y
X = df[['daily.precipIntensityMax', 'current.windGust', 'daily.precipAccumulation','current.temperature','daily.temperatureHigh',]]
label_encode(X, X.columns.values)

# y = df[['NEIGHBORHOOD']]
# y = df['DEPARTMENT']
y = df[['REQUEST_GROUP']]  

label_encode(y, y.columns.values)
# y = y['REQUEST_GROUP']
# Out:
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:10: SettingWithCopyWarning:
# A value is trying to be set on a copy of a slice from a DataFrame.
# Try using .loc[row_indexer,col_indexer] = value instead
#
# See the caveats in the documentation: http://pandas.pydata.org/pandas-docs/stable/indexing.html#indexing-view-versus-copy
#   # Remove the CWD from sys.path while we load stuff.

# %%
X.corr()
# Out:
#                           daily.precipIntensityMax  current.windGust  \
# daily.precipIntensityMax                  1.000000          0.019589
# current.windGust                          0.019589          1.000000
# daily.precipAccumulation                 -0.092303          0.180457
# current.temperature                       0.324229         -0.186243
# daily.temperatureHigh                     0.230018         -0.443524
#
#                           daily.precipAccumulation  current.temperature  \
# daily.precipIntensityMax                 -0.092303             0.324229
# current.windGust                          0.180457            -0.186243
# daily.precipAccumulation                  1.000000            -0.299133
# current.temperature                      -0.299133             1.000000
# daily.temperatureHigh                    -0.358163             0.891066
#
#                           daily.temperatureHigh
# daily.precipIntensityMax               0.230018
# current.windGust                      -0.443524
# daily.precipAccumulation              -0.358163
# current.temperature                    0.891066
# daily.temperatureHigh                  1.000000

# %%
#classify(X, y, classifier='nb', kfolds=10, report=False, features_select=3)
# classify(X, y, classifier='svm', kern='rbf', kfolds=10, report=False, features_select=3)
#X_pca = decompose(X)
#classify(X_pca, y, classifier='svm', kern='rbf', kfolds=10, report=False, features_select=3)
#print(X_pca.shape)
# classify(X, y, classifier='svm', kern='linear', kfolds=10, report=True)
# classify(X, y, classifier='svm', kern='poly', kfolds=10, report=True)
# classify(X, y, classifier='knn', neighbors=3, kfolds=10)
# classify(X, y, classifier='knn', neighbors=5, kfolds=10)
# classify(X, y, classifier='knn', neighbors=7)
# classify(X, y, classifier='rf', neighbors=1000, kfolds=10)
# classify(X, y, classifier='rf', neighbors=2000)
# classify(X, y, classifier='dtree', kfolds=10)
classify(X, y, classifier='logisticregression', kfolds=10, report=True, features_select=5)
# Out:
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Logistic Regression model accuracy score:  0.3944645976084912
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# Cross-validated score: 0.38190953851993364
# Confusion matrix
# [[   0    0    0    0  364    1    0]
#  [   0    0    0    0  859   21    0]
#  [   0    0    0    0  147    2    0]
#  [   0    0    0    0 1608   36    0]
#  [   0    0    0    0 2716   54    0]
#  [   0    0    0    0  977  220    0]
#  [   0    0    0    0  436    2    0]]
# Classification report
#              precision    recall  f1-score   support
#
#         low       0.00      0.00      0.00       365
#         med       0.00      0.00      0.00       880
#        high       0.00      0.00      0.00       149
#
# avg / total       0.25      0.39      0.25      7443
#
# ______________________________
# [('daily.precipIntensityMax', 160104.58115881545), ('current.windGust', 222673.68017020245), ('daily.precipAccumulation', 362324.48368737136), ('current.temperature', 1206519.9106679899), ('daily.temperatureHigh', 1616820.509686216)]
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1428: UserWarning: labels size, 7, does not match size of target_names, 3
#   .format(len(labels), len(target_names))
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)

# %%
classify(X, y, classifier='nb', kfolds=10, report=True, features_select=5)
# Out:
# Naive Bayes model accuracy score:  0.37471449684267094
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1428: UserWarning: labels size, 7, does not match size of target_names, 3
#   .format(len(labels), len(target_names))
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1135: UndefinedMetricWarning: Precision and F-score are ill-defined and being set to 0.0 in labels with no predicted samples.
#   'precision', 'predicted', average, warn_for)
# Cross-validated score: 0.33406463076822124
# Confusion matrix
# [[   0    0    0    0  311   11   43]
#  [   0    0    0    2  723   78   77]
#  [   0    0    0    1  128    8   12]
#  [   0    0    0    2 1305  134  203]
#  [   0    0    0    3 2315  200  252]
#  [   0    0    0    1  699  403   94]
#  [   0    0    0    0  361    8   69]]
# Classification report
#              precision    recall  f1-score   support
#
#         low       0.00      0.00      0.00       365
#         med       0.00      0.00      0.00       880
#        high       0.00      0.00      0.00       149
#
# avg / total       0.28      0.37      0.27      7443
#
# ______________________________
# [('daily.precipIntensityMax', 160104.58115881545), ('current.windGust', 222673.68017020245), ('daily.precipAccumulation', 362324.48368737136), ('current.temperature', 1206519.9106679899), ('daily.temperatureHigh', 1616820.509686216)]

# %%
classify(X, y, classifier='dtree', kfolds=10, report=True, features_select=5)
# Out:
# Decision tree model accuracy score:  0.38076044605669757
# Cross-validated score: 0.22965785838175087
# Confusion matrix
# [[  15   47    1   98  146   39   19]
#  [  30  134    5  203  387   94   27]
#  [   1   20   11   39   61   15    2]
#  [  38  169    7  655  572  160   43]
#  [  67  248   12  592 1557  228   66]
#  [  23  109    4  240  361  429   31]
#  [  16   46    1  135  168   39   33]]
# Classification report
#              precision    recall  f1-score   support
#
#         low       0.08      0.04      0.05       365
#         med       0.17      0.15      0.16       880
#        high       0.27      0.07      0.12       149
#
# avg / total       0.36      0.38      0.37      7443
#
# ______________________________
# [('daily.precipIntensityMax', 160104.58115881545), ('current.windGust', 222673.68017020245), ('daily.precipAccumulation', 362324.48368737136), ('current.temperature', 1206519.9106679899), ('daily.temperatureHigh', 1616820.509686216)]
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py:1428: UserWarning: labels size, 7, does not match size of target_names, 3
#   .format(len(labels), len(target_names))

# %%
classify(X, y, classifier='rf', neighbors=2000, kfolds=10)

# %%
classify(X, y, classifier='rf', neighbors=1000, kfolds=5)
# Out:
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\ipykernel_launcher.py:28: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
# Random Forest with 1000 decision trees model accuracy score:  0.37229611715706035
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\model_selection\_validation.py:458: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples,), for example using ravel().
#   estimator.fit(X_train, y_train, **fit_params)
# Cross-validated score: -1.664199699344795
# Confusion matrix
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-11-a948759cc28d> in <module>()
# ----> 1 classify(X, y, classifier='rf', neighbors=1000, kfolds=5, report=True, features_select=5)
#
# <ipython-input-3-096f5e88520a> in classify(predictors, response, classifier, kern, neighbors, kfolds, report, features_select)
#      37     if report == True:
#      38         print('Confusion matrix')
# ---> 39         print(metrics.confusion_matrix(y_test, y_pred_class)) # confusion matrix
#      40         print('Classification report')
#      41         target_names=['low','med','high']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     248
#     249     """
# --> 250     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     251     if y_type not in ("binary", "multiclass"):
#     252         raise ValueError("%s is not supported" % y_type)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets

# %%
classify(X, y, classifier='knn', neighbors=7, kfolds=10)
# Out:
# KNN with k=7 model accuracy score:  0.33145237135563616
# Cross-validated score: -0.4028439604249354
# Confusion matrix
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-30-6d097c8b8071> in <module>()
# ----> 1 classify(X, y, classifier='knn', neighbors=7, kfolds=10, report=True, features_select=5)
#
# <ipython-input-19-096f5e88520a> in classify(predictors, response, classifier, kern, neighbors, kfolds, report, features_select)
#      37     if report == True:
#      38         print('Confusion matrix')
# ---> 39         print(metrics.confusion_matrix(y_test, y_pred_class)) # confusion matrix
#      40         print('Classification report')
#      41         target_names=['low','med','high']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     248
#     249     """
# --> 250     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     251     if y_type not in ("binary", "multiclass"):
#     252         raise ValueError("%s is not supported" % y_type)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets

# %%
classify(X, y, classifier='knn', neighbors=5, kfolds=10)
# Out:
# KNN with k=5 model accuracy score:  0.32674996641139326
# Cross-validated score: -0.5053361643182367
# Confusion matrix
# ---------------------------------------------------------------------------
# ValueError                                Traceback (most recent call last)
# <ipython-input-31-e490770f1f89> in <module>()
# ----> 1 classify(X, y, classifier='knn', neighbors=5, kfolds=10, report=True, features_select=5)
#
# <ipython-input-19-096f5e88520a> in classify(predictors, response, classifier, kern, neighbors, kfolds, report, features_select)
#      37     if report == True:
#      38         print('Confusion matrix')
# ---> 39         print(metrics.confusion_matrix(y_test, y_pred_class)) # confusion matrix
#      40         print('Classification report')
#      41         target_names=['low','med','high']
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py in confusion_matrix(y_true, y_pred, labels, sample_weight)
#     248
#     249     """
# --> 250     y_type, y_true, y_pred = _check_targets(y_true, y_pred)
#     251     if y_type not in ("binary", "multiclass"):
#     252         raise ValueError("%s is not supported" % y_type)
#
# ~\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\metrics\classification.py in _check_targets(y_true, y_pred)
#      79     if len(y_type) > 1:
#      80         raise ValueError("Classification metrics can't handle a mix of {0} "
# ---> 81                          "and {1} targets".format(type_true, type_pred))
#      82
#      83     # We can't have more than one value on y_type => The set is no more needed
#
# ValueError: Classification metrics can't handle a mix of multiclass and continuous targets

# %%
classify(X, y, classifier='knn', neighbors=3, kfolds=10)
# Out:
# KNN with k=3 model accuracy score:  0.3190917640736262
# Cross-validated score: -0.738117322684249

# %%
# classify(X, y, classifier='svm', kern='poly', kfolds=10, report=True)
# classify(X, y, classifier='svm', kern='linear', kfolds=10, report=True)

# %%
classify(X, y, classifier='svm', kern='rbf', kfolds=10)
# Out:
# C:\Users\boblutz\AppData\Local\Continuum\anaconda3\lib\site-packages\sklearn\utils\validation.py:578: DataConversionWarning: A column-vector y was passed when a 1d array was expected. Please change the shape of y to (n_samples, ), for example using ravel().
#   y = column_or_1d(y, warn=True)

# %%
classify(X, y, classifier='svm', kern='ply', kfolds=10, report=True, features_select=5)

# %%
X_pca = decompose(X)
classify(X_pca, y, classifier='svm', kern='rbf',kfolds=10, report=True, features_select=5)
print(X_pca.shape)
